# %% [markdown]
# <a href="https://colab.research.google.com/github/Esaipriya/AISECT-ML/blob/main/RandomForestRegressor_Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#one hot encoding
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#assign input ,output variables
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
# standard scaler for values standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#assign parameters for random forest regressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'n_estimators': [10, 20, 30, 100],
    'max_depth': [None, 10, 20, 30],
    'max_features': ['sqrt', 'log2'],
    'min_samples_split': [2, 5, 10],
    'bootstrap': [True, False]
}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 20, 30, 100]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100}
# r2: 0.8309955318880362

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 35        0.318721      0.015547         0.021872        0.001955
# 71        0.312218      0.008011         0.020828        0.000496
# 47        0.303521      0.007514         0.021618        0.002019
# 23        0.515263      0.028993         0.036554        0.013265
# 95        0.314138      0.002731         0.025652        0.010406
# ..             ...           ...              ...             ...
# 109       0.089767      0.007510         0.007907        0.000292
# 96        0.047011      0.001799         0.005604        0.000188
# 168       0.045267      0.001032         0.005429        0.000133
# 156       0.045360      0.001777         0.005457        0.000183
# 180       0.057274      0.019038         0.006852        0.002420
#
#      param_bootstrap param_max_depth param_max_features  \
# 35              True              10               sqrt
# 71              True              20               log2
# 47              True              10               log2
# 23              True            None               log2
# 95              True              30               log2
# ..               ...             ...                ...
# 109            False            None               log2
# 96             False            None               sqrt
# 168            False              30               sqrt
# 156            False              20               log2
# 180            False              30               log2
#
#      param_min_samples_split  param_n_estimators  \
# 35                        10                 100
# 71                        10                 100
# 47                        10                 100
# 23                        10                 100
# 95                        10                 100
# ..                       ...                 ...
# 109                        2                  20
# 96                         2                  10
# 168                        2                  10
# 156                        2                  10
# 180                        2                  10
#
#                                                 params  split0_test_score  \
# 35   {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.861039
# 71   {'bootstrap': True, 'max_depth': 20, 'max_feat...           0.858440
# 47   {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.864031
# 23   {'bootstrap': True, 'max_depth': None, 'max_fe...           0.861289
# 95   {'bootstrap': True, 'max_depth': 30, 'max_feat...           0.860893
# ..                                                 ...                ...
# 109  {'bootstrap': False, 'max_depth': None, 'max_f...           0.820010
# 96   {'bootstrap': False, 'max_depth': None, 'max_f...           0.819810
# 168  {'bootstrap': False, 'max_depth': 30, 'max_fea...           0.790571
# 156  {'bootstrap': False, 'max_depth': 20, 'max_fea...           0.819781
# 180  {'bootstrap': False, 'max_depth': 30, 'max_fea...           0.802977
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 35            0.835709           0.827423           0.847944
# 71            0.836057           0.819453           0.849643
# 47            0.837611           0.826535           0.847916
# 23            0.836824           0.819907           0.845790
# 95            0.834924           0.819331           0.846138
# ..                 ...                ...                ...
# 109           0.788440           0.741838           0.808291
# 96            0.788552           0.749743           0.795647
# 168           0.791391           0.756931           0.815251
# 156           0.798573           0.738601           0.793373
# 180           0.779529           0.756060           0.780771
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 35            0.782862         0.830996        0.026615                1
# 71            0.789655         0.830650        0.024365                2
# 47            0.776845         0.830588        0.029573                3
# 23            0.787321         0.830226        0.025290                4
# 95            0.786259         0.829509        0.025554                5
# ..                 ...              ...             ...              ...
# 109           0.750843         0.781884        0.030858              188
# 96            0.748991         0.780549        0.027489              189
# 168           0.741762         0.779181        0.026363              190
# 156           0.721206         0.774307        0.037722              191
# 180           0.733441         0.770556        0.023764              192
#
# [192 rows x 18 columns]

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
#save the model using pickle
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
# Load the saved model from the specified file
loaded_model = pickle.load(open('/content/RF_G.sav', 'rb'))

# %%
loaded_model.predict([[50,0,30.970,3,0]])
# Out:
# array([18730.84804521])

# %%
# Predicting the test set results
y_pred = grid.predict(X_test)

# %%
# Evaluating the model using R2 score
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R-squared score:", r2)
# Out:
# R-squared score: 0.893510955129432

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:19
# BMI:27.900
# Children:0
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[17645.03104112]
