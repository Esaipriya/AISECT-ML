# %% [markdown]
# <a href="https://colab.research.google.com/github/Esaipriya/AISECT-ML/blob/main/linear_reg_grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
#load dataset
dataset=pd.read_csv('/content/insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#one hot encoding
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#assign input ,output variables
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
# standard scaler for values standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#assign parameters for linear regressor
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
param_grid={
     'fit_intercept':[True,False],
     'copy_X':[True,False],
     'n_jobs':[None,1],
     'positive':[False,True]
     }
grid = GridSearchCV(LinearRegression(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=LinearRegression(), n_jobs=-1,
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [None, 1],
#                          'positive': [False, True]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': True}
# r2: 0.7310068903329985

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1        0.001958      0.000066         0.001383        0.000042
# 3        0.001895      0.000077         0.001390        0.000046
# 11       0.001928      0.000075         0.001442        0.000081
# 9        0.002471      0.000455         0.001876        0.000249
# 10       0.001954      0.000079         0.001425        0.000048
# 8        0.001975      0.000080         0.001875        0.000809
# 0        0.002341      0.000322         0.001401        0.000054
# 2        0.001913      0.000093         0.001421        0.000066
# 13       0.001881      0.000033         0.001574        0.000120
# 15       0.001961      0.000329         0.001522        0.000395
# 7        0.001796      0.000056         0.001400        0.000070
# 5        0.001876      0.000105         0.001413        0.000053
# 6        0.001753      0.000040         0.001423        0.000026
# 4        0.001878      0.000125         0.001432        0.000054
# 12       0.002394      0.000972         0.001472        0.000052
# 14       0.002064      0.000225         0.001519        0.000267
#
#     param_copy_X  param_fit_intercept param_n_jobs  param_positive  \
# 1           True                 True         None            True
# 3           True                 True            1            True
# 11         False                 True            1            True
# 9          False                 True         None            True
# 10         False                 True            1           False
# 8          False                 True         None           False
# 0           True                 True         None           False
# 2           True                 True            1           False
# 13         False                False         None            True
# 15         False                False            1            True
# 7           True                False            1            True
# 5           True                False         None            True
# 6           True                False            1           False
# 4           True                False         None           False
# 12         False                False         None           False
# 14         False                False            1           False
#
#                                                params  split0_test_score  \
# 1   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.764057
# 3   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.764057
# 11  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.764057
# 9   {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.764057
# 10  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.764057
# 8   {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.764057
# 0   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.764057
# 2   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.764057
# 13  {'copy_X': False, 'fit_intercept': False, 'n_j...          -0.432616
# 15  {'copy_X': False, 'fit_intercept': False, 'n_j...          -0.432616
# 7   {'copy_X': True, 'fit_intercept': False, 'n_jo...          -0.432616
# 5   {'copy_X': True, 'fit_intercept': False, 'n_jo...          -0.432616
# 6   {'copy_X': True, 'fit_intercept': False, 'n_jo...          -0.432616
# 4   {'copy_X': True, 'fit_intercept': False, 'n_jo...          -0.432616
# 12  {'copy_X': False, 'fit_intercept': False, 'n_j...          -0.432616
# 14  {'copy_X': False, 'fit_intercept': False, 'n_j...          -0.432616
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 1            0.716901           0.736378           0.736118
# 3            0.716901           0.736378           0.736118
# 11           0.716901           0.736378           0.736118
# 9            0.716901           0.736378           0.736118
# 10           0.716149           0.736378           0.736094
# 8            0.716149           0.736378           0.736094
# 0            0.716149           0.736378           0.736094
# 2            0.716149           0.736378           0.736094
# 13          -0.721299          -0.518975          -0.426493
# 15          -0.721299          -0.518975          -0.426493
# 7           -0.721299          -0.518975          -0.426493
# 5           -0.721299          -0.518975          -0.426493
# 6           -0.721299          -0.518975          -0.426602
# 4           -0.721299          -0.518975          -0.426602
# 12          -0.721299          -0.518975          -0.426602
# 14          -0.721299          -0.518975          -0.426602
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 1            0.701581         0.731007        0.021034                1
# 3            0.701581         0.731007        0.021034                1
# 11           0.701581         0.731007        0.021034                1
# 9            0.701581         0.731007        0.021034                1
# 10           0.701579         0.730851        0.021136                5
# 8            0.701579         0.730851        0.021136                5
# 0            0.701579         0.730851        0.021136                5
# 2            0.701579         0.730851        0.021136                5
# 13          -0.468372        -0.513551        0.108958                9
# 15          -0.468372        -0.513551        0.108958                9
# 7           -0.468372        -0.513551        0.108958                9
# 5           -0.468372        -0.513551        0.108958                9
# 6           -0.472680        -0.514434        0.108596               13
# 4           -0.472680        -0.514434        0.108596               13
# 12          -0.472680        -0.514434        0.108596               13
# 14          -0.472680        -0.514434        0.108596               13

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
#save the model using pickle
import pickle
filename="linearreg_Grid.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
# Load the saved model from the specified file
loaded_model = pickle.load(open('/content/linearreg_Grid.sav', 'rb'))

# %%
#output
loaded_model.predict([[50,0,30.970,3,0]])
# Out:
# array([[208854.37141692]])

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print("R-squared score:", r2)
# Out:
# R-squared score: 0.7978274606303823

# %%
#get input from user
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:50
# BMI:30.970
# Children:3
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:0

# %%
#output
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[[255685.1351218]]
